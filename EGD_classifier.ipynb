# %% [markdown]
# # Training and evaluation of fine-tuned pre-trained efficientnetV2 on EGD Barcelona dataset
#
# remember to load dataloader.py and efficientnet.py, these can be found on my github:
#
#
# 1.   [dataloader.py](https://github.com/Neilus03/gastroscopy_attention_classifier/blob/e0a605d84cc48c31753696225912b56b1bacf63a/dataloader.py)
# 2.   [efficientnet.py](https://github.com/Neilus03/gastroscopy_attention_classifier/blob/main/efficientnet.py)

# %%
from efficientnet import initialize_model
from dataloader import EGDDataset

# %% [markdown]
# ## Train the model without Kfold cross validation, in a naive way, splitting dataset 85% train 15% val

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import random_split, DataLoader
import numpy as np
from efficientnet import initialize_model
from dataloader import EGDDataset
from torchvision import transforms
from torch.utils.tensorboard import SummaryWriter
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Initialize TensorBoard SummaryWriter
writer = SummaryWriter()

# Initialize dataset
transform = transforms.Compose([
    transforms.Resize((300, 340)),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])
dataset = EGDDataset(
    image_folder="/content/drive/MyDrive/EGD-Barcelona/merged/all_images_mean_cropped",
    label_file="/content/drive/MyDrive/EGD-Barcelona/merged/full_well.xlsx",
    transform=transform
)

# Split data into training, validation, and test sets
total_samples = len(dataset)
train_size = int(0.85 * total_samples)
val_size = total_samples - train_size

train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# Initialize DataLoader
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# Hyperparameters
num_epochs = 40
learning_rate = 1e-4

# Initialize the model and optimizer
num_classes = 3
model = initialize_model(num_classes)
optimizer = optim.Adam(model.parameters(), lr=learning_rate )

# Loss function
criterion = nn.CrossEntropyLoss()

# Initialize lists to store losses and accuracies
train_losses = []
val_losses = []
val_accuracies = []

# Train the model
for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for i, (images, individual_labels, final_label) in enumerate(train_loader):
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, final_label)

        # Backward pass and optimization
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    train_losses.append(running_loss / len(train_loader))

    model.eval()
    val_loss = 0.0
    correct = 0
    total = 0

    conf_mat = np.zeros((num_classes, num_classes))

    with torch.no_grad():
        for images,individual_labels, final_label  in val_loader:
            outputs = model(images)
            loss = criterion(outputs, final_label)
            val_loss += loss.item()

            _, predicted = torch.max(outputs.data, 1)
            total += final_label.size(0)
            correct += (predicted == final_label).sum().item()

            conf_mat += confusion_matrix(final_label.cpu(), predicted.cpu(), labels=range(num_classes))

    val_loss = val_loss / len(val_loader)
    val_losses.append(val_loss)
    val_accuracies.append(100 * correct / total)

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {100 * correct / total:.2f}%')
    print(f"correctly classified: {correct}, incorrectly classified: {total-correct}")
    sns.heatmap(conf_mat, annot=True,cmap='cool')
    plt.title("Classification confusion matrix")
    plt.ylabel("Actual label")
    plt.xlabel("Predicted as")
    plt.show()

    # Calculate and print per-class accuracy and recall
    for i in range(num_classes):
        tp = conf_mat[i, i]
        fn = np.sum(conf_mat[i, :]) - tp
        fp = np.sum(conf_mat[:, i]) - tp
        tn = np.sum(conf_mat) - tp - fn - fp

        accuracy = (tp + tn) / np.sum(conf_mat)
        recall = tp / (tp + fn)

        print(f'Class {i} Accuracy: {accuracy * 100:.2f}%')
        print(f'Class {i} Recall: {recall * 100:.2f}%')
        print("\n")
    print("\n\n")
    print("---------------------------------------------")
# Out:
# Epoch [1/40], Loss: 8.0635, Val Loss: 0.9939, Val Accuracy: 52.63%
# correctly classified: 10, incorrectly classified: 9
# Class 0 Accuracy: 63.16%
# Class 0 Recall: 80.00%
#
#
# Class 1 Accuracy: 68.42%
# Class 1 Recall: 0.00%
#
#
# Class 2 Accuracy: 73.68%
# Class 2 Recall: 60.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch

# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 94.74%
# Class 1 Recall: 75.00%
#
#
# Class 2 Accuracy: 100.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [25/40], Loss: 1.3656, Val Loss: 0.5507, Val Accuracy: 73.68%
# correctly classified: 14, incorrectly classified: 5
# Class 0 Accuracy: 73.68%
# Class 0 Recall: 80.00%
#
#
# Class 1 Accuracy: 84.21%
# Class 1 Recall: 50.00%
#
#
# Class 2 Accuracy: 89.47%
# Class 2 Recall: 80.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [26/40], Loss: 0.9252, Val Loss: 0.3095, Val Accuracy: 84.21%
# correctly classified: 16, incorrectly classified: 3
# Class 0 Accuracy: 89.47%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 84.21%
# Class 1 Recall: 50.00%
#
#
# Class 2 Accuracy: 94.74%
# Class 2 Recall: 90.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [27/40], Loss: 1.3037, Val Loss: 0.2922, Val Accuracy: 94.74%
# correctly classified: 18, incorrectly classified: 1
# Class 0 Accuracy: 100.00%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 94.74%
# Class 1 Recall: 100.00%
#
#
# Class 2 Accuracy: 94.74%
# Class 2 Recall: 90.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [28/40], Loss: 0.8027, Val Loss: 0.2341, Val Accuracy: 94.74%
# correctly classified: 18, incorrectly classified: 1
# Class 0 Accuracy: 94.74%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 94.74%
# Class 1 Recall: 75.00%
#
#
# Class 2 Accuracy: 100.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [29/40], Loss: 0.6688, Val Loss: 0.5231, Val Accuracy: 73.68%
# correctly classified: 14, incorrectly classified: 5
# Class 0 Accuracy: 84.21%
# Class 0 Recall: 80.00%
#
#
# Class 1 Accuracy: 78.95%
# Class 1 Recall: 50.00%
#
#
# Class 2 Accuracy: 84.21%
# Class 2 Recall: 80.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [30/40], Loss: 1.1234, Val Loss: 0.2838, Val Accuracy: 94.74%
# correctly classified: 18, incorrectly classified: 1
# Class 0 Accuracy: 100.00%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 94.74%
# Class 1 Recall: 100.00%
#
#
# Class 2 Accuracy: 94.74%
# Class 2 Recall: 90.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [31/40], Loss: 1.9236, Val Loss: 0.5431, Val Accuracy: 78.95%
# correctly classified: 15, incorrectly classified: 4
# Class 0 Accuracy: 84.21%
# Class 0 Recall: 80.00%
#
#
# Class 1 Accuracy: 84.21%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 89.47%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [32/40], Loss: 1.4003, Val Loss: 0.3536, Val Accuracy: 89.47%
# correctly classified: 17, incorrectly classified: 2
# Class 0 Accuracy: 94.74%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 89.47%
# Class 1 Recall: 75.00%
#
#
# Class 2 Accuracy: 94.74%
# Class 2 Recall: 90.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [33/40], Loss: 0.5905, Val Loss: 0.3529, Val Accuracy: 89.47%
# correctly classified: 17, incorrectly classified: 2
# Class 0 Accuracy: 89.47%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 94.74%
# Class 1 Recall: 75.00%
#
#
# Class 2 Accuracy: 94.74%
# Class 2 Recall: 90.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [34/40], Loss: 0.7696, Val Loss: 0.3399, Val Accuracy: 84.21%
# correctly classified: 16, incorrectly classified: 3
# Class 0 Accuracy: 89.47%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 89.47%
# Class 1 Recall: 50.00%
#
#
# Class 2 Accuracy: 89.47%
# Class 2 Recall: 90.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [35/40], Loss: 1.1946, Val Loss: 0.6142, Val Accuracy: 78.95%
# correctly classified: 15, incorrectly classified: 4
# Class 0 Accuracy: 78.95%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 84.21%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 94.74%
# Class 2 Recall: 90.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [36/40], Loss: 0.5423, Val Loss: 0.4282, Val Accuracy: 84.21%
# correctly classified: 16, incorrectly classified: 3
# Class 0 Accuracy: 89.47%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 84.21%
# Class 1 Recall: 50.00%
#
#
# Class 2 Accuracy: 94.74%
# Class 2 Recall: 90.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [37/40], Loss: 0.8416, Val Loss: 0.3400, Val Accuracy: 84.21%
# correctly classified: 16, incorrectly classified: 3
# Class 0 Accuracy: 89.47%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 89.47%
# Class 1 Recall: 75.00%
#
#
# Class 2 Accuracy: 89.47%
# Class 2 Recall: 80.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [38/40], Loss: 0.3840, Val Loss: 0.5644, Val Accuracy: 78.95%
# correctly classified: 15, incorrectly classified: 4
# Class 0 Accuracy: 84.21%
# Class 0 Recall: 80.00%
#
#
# Class 1 Accuracy: 84.21%
# Class 1 Recall: 50.00%
#
#
# Class 2 Accuracy: 89.47%
# Class 2 Recall: 90.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [39/40], Loss: 0.8178, Val Loss: 0.4479, Val Accuracy: 84.21%
# correctly classified: 16, incorrectly classified: 3
# Class 0 Accuracy: 89.47%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 89.47%
# Class 1 Recall: 75.00%
#
#
# Class 2 Accuracy: 89.47%
# Class 2 Recall: 80.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [40/40], Loss: 0.7926, Val Loss: 0.4460, Val Accuracy: 78.95%
# correctly classified: 15, incorrectly classified: 4
# Class 0 Accuracy: 89.47%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 84.21%
# Class 1 Recall: 75.00%
#
#
# Class 2 Accuracy: 84.21%
# Class 2 Recall: 70.00%
#
#
#
#
#
# ---------------------------------------------

# %% [markdown]
# ## Train and evaluate the model with k-fold cross validation. We´ll store the best weights for each kfold and later on we´ll average them

# %%
from sklearn.model_selection import KFold
import numpy as np
import torch
from torch.utils.data import DataLoader, Subset
from dataloader import EGDDataset
from efficientnet import initialize_model
import torch.optim as optim
import torch.nn as nn
from torchvision import transforms
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Initialize TensorBoard SummaryWriter
# writer = SummaryWriter()

# Initialize dataset
transform = transforms.Compose([
    transforms.Resize((300, 340)),
    transforms.RandomResizedCrop(224),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(10),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

dataset = EGDDataset(
    image_folder="/content/drive/MyDrive/EGD-Barcelona/merged/all_images_mean_cropped",
    label_file="/content/drive/MyDrive/EGD-Barcelona/merged/full_well.xlsx",
    transform=transform
)

# Initialize KFold
n_splits = 5
kfold = KFold(n_splits=n_splits, shuffle=True)

# Hyperparameters
num_epochs = 20
learning_rate = 1e-4
num_classes = 3
batch_size = 16

# Initialize sum of state_dicts to zero, for calculating mean later
sum_state_dict = None

# K-Fold Cross Validation
for fold, (train_ids, val_ids) in enumerate(kfold.split(dataset)):
    best_val_loss = float('inf')

    print(f"FOLD {fold}")
    print("--------------------------------")

    # Define train and validation data subsets
    train_subsampler = Subset(dataset, train_ids)
    val_subsampler = Subset(dataset, val_ids)

    # Initialize DataLoader with batch_size
    train_loader = DataLoader(train_subsampler, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_subsampler, batch_size=batch_size, shuffle=False)

    # Initialize the model and optimizer
    model = initialize_model(num_classes)
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)
    criterion = nn.CrossEntropyLoss()

    train_losses, val_losses, val_accuracies = [], [], []

    for epoch in range(num_epochs):
        model.train()
        running_loss = 0.0


        for i, (images, individual_labels, final_label) in enumerate(train_loader):
            outputs = model(images)
            loss = criterion(outputs, final_label)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            running_loss += loss.item()

        train_losses.append(running_loss / len(train_loader))

        model.eval()
        val_loss = 0.0
        correct, total = 0, 0

        conf_mat = np.zeros((num_classes, num_classes))

        with torch.no_grad():
            for images, individual_labels, final_label in val_loader:
                outputs = model(images)
                loss = criterion(outputs, final_label)

                val_loss += loss.item()

                _, predicted = torch.max(outputs.data, 1)
                total += final_label.size(0)
                correct += (predicted == final_label).sum().item()

                conf_mat += confusion_matrix(final_label.cpu(), predicted.cpu(), labels=range(num_classes))

        val_loss /= len(val_loader)
        val_losses.append(val_loss)
        val_accuracies.append(100 * correct / total)

        if val_loss < best_val_loss:
            best_val_loss = val_loss
            torch.save(model.state_dict(), f"/content/drive/MyDrive/EGD-Barcelona/merged/effnet_weights/best_model_fold_{fold}.pth")

        print(f"Epoch [{epoch + 1}/{num_epochs}], Loss: {running_loss:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {100 * correct / total:.2f}%")
        print(f"correctly classified: {correct}, incorrectly classified: {total-correct}")

        sns.heatmap(conf_mat, annot=True, cmap='cool')
        plt.title("Classification confusion matrix")
        plt.ylabel("Actual label")
        plt.xlabel("Predicted as")
        plt.show()

        # Calculate and print per-class accuracy and recall
        for i in range(num_classes):
            tp = conf_mat[i, i]
            fn = np.sum(conf_mat[i, :]) - tp
            fp = np.sum(conf_mat[:, i]) - tp
            tn = np.sum(conf_mat) - tp - fn - fp

            accuracy = (tp + tn) / np.sum(conf_mat)
            recall = tp / (tp + fn)

            print(f'Class {i} Accuracy: {accuracy * 100:.2f}%')
            print(f'Class {i} Recall: {recall * 100:.2f}%')
            print("\n")
        print("\n\n")
        print("---------------------------------------------")

    # Accumulate state_dicts for later averaging
    if sum_state_dict is None:
        sum_state_dict = model.state_dict()
    else:
        for key in sum_state_dict.keys():
            sum_state_dict[key] += model.state_dict()[key]

# Calculate mean state_dict
for key in sum_state_dict.keys():
    sum_state_dict[key] /= n_splits

# Load mean state_dict into a fresh model
mean_model = initialize_model(num_classes)
mean_model.load_state_dict(sum_state_dict)
torch.save(mean_model.state_dict(), "mean_model.pth")
# Out:
# FOLD 0
# --------------------------------
# Using cache found in /root/.cache/torch/hub/hankyul2_EfficientNetV2-pytorch_main
# Epoch [1/20], Loss: 7.8681, Val Loss: 1.1574, Val Accuracy: 28.00%
# correctly classified: 7, incorrectly classified: 18
# Class 0 Accuracy: 64.00%
# Class 0 Recall: 0.00%
#
#
# Class 1 Accuracy: 44.00%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 48.00%
# Class 2 Recall: 55.56%
#
#
#
#
#
# ---------------------------------------------
# Epoch [2/20], Loss: 5.9117, Val Loss: 0.9722, Val Accuracy: 48.00%
# correctly classified: 12, incorrectly classified: 13
# Class 0 Accuracy: 68.00%
# Class 0 Recall: 25.00%
#
#
# Class 1 Accuracy: 56.00%
# Class 1 Recall: 37.50%
#
#
# Class 2 Accuracy:

#
#
# Class 1 Accuracy: 68.00%
# Class 1 Recall: 16.67%
#
#
# Class 2 Accuracy: 88.00%
# Class 2 Recall: 90.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [8/20], Loss: 3.0044, Val Loss: 0.7157, Val Accuracy: 72.00%
# correctly classified: 18, incorrectly classified: 7
# Class 0 Accuracy: 76.00%
# Class 0 Recall: 77.78%
#
#
# Class 1 Accuracy: 72.00%
# Class 1 Recall: 16.67%
#
#
# Class 2 Accuracy: 96.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [9/20], Loss: 2.5943, Val Loss: 0.5852, Val Accuracy: 76.00%
# correctly classified: 19, incorrectly classified: 6
# Class 0 Accuracy: 80.00%
# Class 0 Recall: 88.89%
#
#
# Class 1 Accuracy: 80.00%
# Class 1 Recall: 16.67%
#
#
# Class 2 Accuracy: 92.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [10/20], Loss: 3.0358, Val Loss: 0.6735, Val Accuracy: 72.00%
# correctly classified: 18, incorrectly classified: 7
# Class 0 Accuracy: 80.00%
# Class 0 Recall: 88.89%
#
#
# Class 1 Accuracy: 72.00%
# Class 1 Recall: 0.00%
#
#
# Class 2 Accuracy: 92.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [11/20], Loss: 4.8144, Val Loss: 0.8792, Val Accuracy: 60.00%
# correctly classified: 15, incorrectly classified: 10
# Class 0 Accuracy: 68.00%
# Class 0 Recall: 55.56%
#
#
# Class 1 Accuracy: 60.00%
# Class 1 Recall: 0.00%
#
#
# Class 2 Accuracy: 92.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [12/20], Loss: 3.1823, Val Loss: 0.6194, Val Accuracy: 76.00%
# correctly classified: 19, incorrectly classified: 6
# Class 0 Accuracy: 84.00%
# Class 0 Recall: 88.89%
#
#
# Class 1 Accuracy: 76.00%
# Class 1 Recall: 16.67%
#
#
# Class 2 Accuracy: 92.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [13/20], Loss: 2.0825, Val Loss: 0.9800, Val Accuracy: 60.00%
# correctly classified: 15, incorrectly classified: 10
# Class 0 Accuracy: 76.00%
# Class 0 Recall: 66.67%
#
#
# Class 1 Accuracy: 64.00%
# Class 1 Recall: 0.00%
#
#
# Class 2 Accuracy: 80.00%
# Class 2 Recall: 90.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [14/20], Loss: 2.5793, Val Loss: 0.9691, Val Accuracy: 68.00%
# correctly classified: 17, incorrectly classified: 8
# Class 0 Accuracy: 76.00%
# Class 0 Recall: 77.78%
#
#
# Class 1 Accuracy: 68.00%
# Class 1 Recall: 0.00%
#
#
# Class 2 Accuracy: 92.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [15/20], Loss: 1.8939, Val Loss: 0.7798, Val Accuracy: 72.00%
# correctly classified: 18, incorrectly classified: 7
# Class 0 Accuracy: 80.00%
# Class 0 Recall: 77.78%
#
#
# Class 1 Accuracy: 84.00%
# Class 1 Recall: 33.33%
#
#
# Class 2 Accuracy: 80.00%
# Class 2 Recall: 90.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [16/20], Loss: 2.6760, Val Loss: 0.5952, Val Accuracy: 84.00%
# correctly classified: 21, incorrectly classified: 4
# Class 0 Accuracy: 92.00%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 84.00%
# Class 1 Recall: 33.33%
#
#
# Class 2 Accuracy: 92.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [17/20], Loss: 1.6262, Val Loss: 0.6628, Val Accuracy: 72.00%
# correctly classified: 18, incorrectly classified: 7
# Class 0 Accuracy: 80.00%
# Class 0 Recall: 66.67%
#
#
# Class 1 Accuracy: 72.00%
# Class 1 Recall: 33.33%
#
#
# Class 2 Accuracy: 92.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [18/20], Loss: 3.4559, Val Loss: 0.4186, Val Accuracy: 88.00%
# correctly classified: 22, incorrectly classified: 3
# Class 0 Accuracy: 96.00%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 88.00%
# Class 1 Recall: 50.00%
#
#
# Class 2 Accuracy: 92.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [19/20], Loss: 1.7962, Val Loss: 0.5691, Val Accuracy: 76.00%
# correctly classified: 19, incorrectly classified: 6
# Class 0 Accuracy: 80.00%
# Class 0 Recall: 88.89%
#
#
# Class 1 Accuracy: 80.00%
# Class 1 Recall: 50.00%
#
#
# Class 2 Accuracy: 92.00%
# Class 2 Recall: 80.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [20/20], Loss: 1.6544, Val Loss: 0.8844, Val Accuracy: 64.00%
# correctly classified: 16, incorrectly classified: 9
# Class 0 Accuracy: 68.00%
# Class 0 Recall: 66.67%
#
#
# Class 1 Accuracy: 64.00%
# Class 1 Recall: 16.67%
#
#
# Class 2 Accuracy: 96.00%
# Class 2 Recall: 90.00%
#
#
#
#
#
# ---------------------------------------------
# FOLD 2
# --------------------------------
# Using cache found in /root/.cache/torch/hub/hankyul2_EfficientNetV2-pytorch_main
# Epoch [1/20], Loss: 8.6208, Val Loss: 1.0354, Val Accuracy: 52.00%
# correctly classified: 13, incorrectly classified: 12
# Class 0 Accuracy: 80.00%
# Class 0 Recall: 71.43%
#
#
# Class 1 Accuracy: 56.00%
# Class 1 Recall: 30.00%
#
#
# Class 2 Accuracy: 68.00%
# Class 2 Recall: 62.50%
#
#
#
#
#
# ---------------------------------------------
# Epoch [2/20], Loss: 6.6818, Val Loss: 0.9208, Val Accuracy: 60.00%
# correctly classified: 15, incorrectly classified: 10
# Class 0 Accuracy: 72.00%
# Class 0 Recall: 57.14%
#
#
# Class 1 Accuracy: 68.00%
# Class 1 Recall: 30.00%
#
#
# Class 2 Accuracy: 80.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [3/20], Loss: 4.6892, Val Loss: 0.8785, Val Accuracy: 60.00%
# correctly classified: 15, incorrectly classified: 10
# Class 0 Accuracy: 68.00%
# Class 0 Recall: 71.43%
#
#
# Class 1 Accuracy: 68.00%
# Class 1 Recall: 30.00%
#
#
# Class 2 Accuracy: 84.00%
# Class 2 Recall: 87.50%
#
#
#
#
#
# ---------------------------------------------
# Epoch [4/20], Loss: 4.2959, Val Loss: 0.9908, Val Accuracy: 64.00%
# correctly classified: 16, incorrectly classified: 9
# Class 0 Accuracy: 80.00%
# Class 0 Recall: 71.43%
#
#
# Class 1 Accuracy: 72.00%
# Class 1 Recall: 40.00%
#
#
# Class 2 Accuracy: 76.00%
# Class 2 Recall: 87.50%
#
#
#
#
#
# ---------------------------------------------
# Epoch [5/20], Loss: 3.9985, Val Loss: 0.7168, Val Accuracy: 72.00%
# correctly classified: 18, incorrectly classified: 7
# Class 0 Accuracy: 92.00%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 72.00%
# Class 1 Recall: 30.00%
#
#
# Class 2 Accuracy: 80.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [6/20], Loss: 4.2065, Val Loss: 0.9660, Val Accuracy: 44.00%
# correctly classified: 11, incorrectly classified: 14
# Class 0 Accuracy: 64.00%
# Class 0 Recall: 42.86%
#
#
# Class 1 Accuracy: 52.00%
# Class 1 Recall: 20.00%
#
#
# Class 2 Accuracy: 72.00%
# Class 2 Recall: 75.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [7/20], Loss: 3.1795, Val Loss: 0.8387, Val Accuracy: 68.00%
# correctly classified: 17, incorrectly classified: 8
# Class 0 Accuracy: 84.00%
# Class 0 Recall: 85.71%
#
#
# Class 1 Accuracy: 72.00%
# Class 1 Recall: 40.00%
#
#
# Class 2 Accuracy: 80.00%
# Class 2 Recall: 87.50%
#
#
#
#
#
# ---------------------------------------------
# Epoch [8/20], Loss: 3.5159, Val Loss: 0.8212, Val Accuracy: 64.00%
# correctly classified: 16, incorrectly classified: 9
# Class 0 Accuracy: 84.00%
# Class 0 Recall: 71.43%
#
#
# Class 1 Accuracy: 64.00%
# Class 1 Recall: 30.00%
#
#
# Class 2 Accuracy: 80.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [9/20], Loss: 3.1708, Val Loss: 0.6367, Val Accuracy: 72.00%
# correctly classified: 18, incorrectly classified: 7
# Class 0 Accuracy: 80.00%
# Class 0 Recall: 71.43%
#
#
# Class 1 Accuracy: 76.00%
# Class 1 Recall: 50.00%
#
#
# Class 2 Accuracy: 88.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [10/20], Loss: 3.1804, Val Loss: 0.7379, Val Accuracy: 64.00%
# correctly classified: 16, incorrectly classified: 9
# Class 0 Accuracy: 80.00%
# Class 0 Recall: 71.43%
#
#
# Class 1 Accuracy: 68.00%
# Class 1 Recall: 30.00%
#
#
# Class 2 Accuracy: 80.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [11/20], Loss: 2.8402, Val Loss: 1.0498, Val Accuracy: 60.00%
# correctly classified: 15, incorrectly classified: 10
# Class 0 Accuracy: 84.00%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 64.00%
# Class 1 Recall:

#
#
# Class 1 Accuracy: 72.00%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 80.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [19/20], Loss: 1.6041, Val Loss: 0.7542, Val Accuracy: 60.00%
# correctly classified: 15, incorrectly classified: 10
# Class 0 Accuracy: 76.00%
# Class 0 Recall: 42.86%
#
#
# Class 1 Accuracy: 64.00%
# Class 1 Recall: 50.00%
#
#
# Class 2 Accuracy: 80.00%
# Class 2 Recall: 80.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [20/20], Loss: 2.1426, Val Loss: 0.7543, Val Accuracy: 60.00%
# correctly classified: 15, incorrectly classified: 10
# Class 0 Accuracy: 76.00%
# Class 0 Recall: 57.14%
#
#
# Class 1 Accuracy: 64.00%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 80.00%
# Class 2 Recall: 90.00%
#
#
#
#
#
# ---------------------------------------------
# FOLD 4
# --------------------------------
# Using cache found in /root/.cache/torch/hub/hankyul2_EfficientNetV2-pytorch_main
# Epoch [1/20], Loss: 8.6224, Val Loss: 1.2059, Val Accuracy: 36.00%
# correctly classified: 9, incorrectly classified: 16
# Class 0 Accuracy: 52.00%
# Class 0 Recall: 0.00%
#
#
# Class 1 Accuracy: 48.00%
# Class 1 Recall: 100.00%
#
#
# Class 2 Accuracy: 72.00%
# Class 2 Recall: 55.56%
#
#
#
#
#
# ---------------------------------------------
# Epoch [2/20], Loss: 6.3874, Val Loss: 1.1212, Val Accuracy: 48.00%
# correctly classified: 12, incorrectly classified: 13
# Class 0 Accuracy: 68.00%
# Class 0 Recall: 33.33%
#
#
# Class 1 Accuracy: 52.00%
# Class 1 Recall: 75.00%
#
#
# Class 2 Accuracy: 76.00%
# Class 2 Recall: 55.56%
#
#
#
#
#
# ---------------------------------------------
# Epoch [3/20], Loss: 6.4809, Val Loss: 0.9088, Val Accuracy: 68.00%
# correctly classified: 17, incorrectly classified: 8
# Class 0 Accuracy: 80.00%
# Class 0 Recall: 75.00%
#
#
# Class 1 Accuracy: 80.00%
# Class 1 Recall: 50.00%
#
#
# Class 2 Accuracy: 76.00%
# Class 2 Recall: 66.67%
#
#
#
#
#
# ---------------------------------------------
# Epoch [4/20], Loss: 6.0408, Val Loss: 0.7652, Val Accuracy: 72.00%
# correctly classified: 18, incorrectly classified: 7
# Class 0 Accuracy: 84.00%
# Class 0 Recall: 83.33%
#
#
# Class 1 Accuracy: 80.00%
# Class 1 Recall: 50.00%
#
#
# Class 2 Accuracy: 80.00%
# Class 2 Recall: 66.67%
#
#
#
#
#
# ---------------------------------------------
# Epoch [5/20], Loss: 5.1891, Val Loss: 0.7845, Val Accuracy: 68.00%
# correctly classified: 17, incorrectly classified: 8
# Class 0 Accuracy: 80.00%
# Class 0 Recall: 75.00%
#
#
# Class 1 Accuracy: 72.00%
# Class 1 Recall: 0.00%
#
#
# Class 2 Accuracy: 84.00%
# Class 2 Recall: 88.89%
#
#
#
#
#
# ---------------------------------------------
# Epoch [6/20], Loss: 4.1376, Val Loss: 0.7074, Val Accuracy: 76.00%
# correctly classified: 19, incorrectly classified: 6
# Class 0 Accuracy: 80.00%
# Class 0 Recall: 83.33%
#
#
# Class 1 Accuracy: 80.00%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 92.00%
# Class 2 Recall: 88.89%
#
#
#
#
#
# ---------------------------------------------
# Epoch [7/20], Loss: 4.1463, Val Loss: 0.7151, Val Accuracy: 64.00%
# correctly classified: 16, incorrectly classified: 9
# Class 0 Accuracy: 72.00%
# Class 0 Recall: 66.67%
#
#
# Class 1 Accuracy: 68.00%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 88.00%
# Class 2 Recall: 77.78%
#
#
#
#
#
# ---------------------------------------------
# Epoch [8/20], Loss: 3.1710, Val Loss: 0.5621, Val Accuracy: 72.00%
# correctly classified: 18, incorrectly classified: 7
# Class 0 Accuracy: 84.00%
# Class 0 Recall: 83.33%
#
#
# Class 1 Accuracy: 84.00%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 76.00%
# Class 2 Recall: 77.78%
#
#
#
#
#
# ---------------------------------------------
# Epoch [9/20], Loss: 3.2698, Val Loss: 0.6272, Val Accuracy: 76.00%
# correctly classified: 19, incorrectly classified: 6
# Class 0 Accuracy: 88.00%
# Class 0 Recall: 83.33%
#
#
# Class 1 Accuracy: 80.00%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 84.00%
# Class 2 Recall: 88.89%
#
#
#
#
#
# ---------------------------------------------
# Epoch [10/20], Loss: 3.1278, Val Loss: 0.5476, Val Accuracy: 76.00%
# correctly classified: 19, incorrectly classified: 6
# Class 0 Accuracy: 84.00%
# Class 0 Recall: 91.67%
#
#
# Class 1 Accuracy: 76.00%
# Class 1 Recall: 0.00%
#
#
# Class 2 Accuracy: 92.00%
# Class 2 Recall: 88.89%
#
#
#
#
#
# ---------------------------------------------
# Epoch [11/20], Loss: 2.7746, Val Loss: 0.4673, Val Accuracy: 84.00%
# correctly classified: 21, incorrectly classified: 4
# Class 0 Accuracy: 84.00%
# Class 0 Recall: 91.67%
#
#
# Class 1 Accuracy: 88.00%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 96.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [12/20], Loss: 2.7982, Val Loss: 0.5457, Val Accuracy: 76.00%
# correctly classified: 19, incorrectly classified: 6
# Class 0 Accuracy: 84.00%
# Class 0 Recall: 91.67%
#
#
# Class 1 Accuracy: 80.00%
# Class 1 Recall: 0.00%
#
#
# Class 2 Accuracy: 88.00%
# Class 2 Recall: 88.89%
#
#
#
#
#
# ---------------------------------------------
# Epoch [13/20], Loss: 3.1663, Val Loss: 0.5214, Val Accuracy: 80.00%
# correctly classified: 20, incorrectly classified: 5
# Class 0 Accuracy: 88.00%
# Class 0 Recall: 91.67%
#
#
# Class 1 Accuracy: 80.00%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 92.00%
# Class 2 Recall: 88.89%
#
#
#
#
#
# ---------------------------------------------
# Epoch [14/20], Loss: 1.7701, Val Loss: 0.4759, Val Accuracy: 84.00%
# correctly classified: 21, incorrectly classified: 4
# Class 0 Accuracy: 84.00%
# Class 0 Recall: 91.67%
#
#
# Class 1 Accuracy: 88.00%
# Class 1 Recall: 50.00%
#
#
# Class 2 Accuracy: 96.00%
# Class 2 Recall: 88.89%
#
#
#
#
#
# ---------------------------------------------
# Epoch [15/20], Loss: 4.6448, Val Loss: 0.5721, Val Accuracy: 76.00%
# correctly classified: 19, incorrectly classified: 6
# Class 0 Accuracy: 76.00%
# Class 0 Recall: 83.33%
#
#
# Class 1 Accuracy: 84.00%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 92.00%
# Class 2 Recall: 88.89%
#
#
#
#
#
# ---------------------------------------------
# Epoch [16/20], Loss: 2.8630, Val Loss: 0.4122, Val Accuracy: 80.00%
# correctly classified: 20, incorrectly classified: 5
# Class 0 Accuracy: 88.00%
# Class 0 Recall: 91.67%
#
#
# Class 1 Accuracy: 84.00%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 88.00%
# Class 2 Recall: 88.89%
#
#
#
#
#
# ---------------------------------------------
# Epoch [17/20], Loss: 2.7046, Val Loss: 0.6547, Val Accuracy: 84.00%
# correctly classified: 21, incorrectly classified: 4
# Class 0 Accuracy: 92.00%
# Class 0 Recall: 100.00%
#
#
# Class 1 Accuracy: 84.00%
# Class 1 Recall: 0.00%
#
#
# Class 2 Accuracy: 92.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [18/20], Loss: 2.2918, Val Loss: 0.6459, Val Accuracy: 76.00%
# correctly classified: 19, incorrectly classified: 6
# Class 0 Accuracy: 84.00%
# Class 0 Recall: 75.00%
#
#
# Class 1 Accuracy: 84.00%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 84.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [19/20], Loss: 1.8479, Val Loss: 0.6268, Val Accuracy: 72.00%
# correctly classified: 18, incorrectly classified: 7
# Class 0 Accuracy: 80.00%
# Class 0 Recall: 75.00%
#
#
# Class 1 Accuracy: 80.00%
# Class 1 Recall: 0.00%
#
#
# Class 2 Accuracy: 84.00%
# Class 2 Recall: 100.00%
#
#
#
#
#
# ---------------------------------------------
# Epoch [20/20], Loss: 2.1870, Val Loss: 0.5656, Val Accuracy: 80.00%
# correctly classified: 20, incorrectly classified: 5
# Class 0 Accuracy: 92.00%
# Class 0 Recall: 91.67%
#
#
# Class 1 Accuracy: 84.00%
# Class 1 Recall: 25.00%
#
#
# Class 2 Accuracy: 84.00%
# Class 2 Recall: 88.89%
#
#
#
#
#
# ---------------------------------------------
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-3-eba491e01bbe> in <cell line: 145>()
#     144 # Calculate mean state_dict
#     145 for key in sum_state_dict.keys():
# --> 146     sum_state_dict[key] /= n_splits
#     147
#     148 # Load mean state_dict into a fresh model
#
# RuntimeError: result type Float can't be cast to the desired output type Long

# %% [markdown]
# ## Save average weights of the best model for each kfold, resulting in a single set of weights representing the "best" model

# %%
model_paths = ['/content/drive/MyDrive/EGD-Barcelona/merged/effnet_weights/best_model_fold_0.pth',
               '/content/drive/MyDrive/EGD-Barcelona/merged/effnet_weights/best_model_fold_1.pth',
               '/content/drive/MyDrive/EGD-Barcelona/merged/effnet_weights/best_model_fold_2.pth',
               '/content/drive/MyDrive/EGD-Barcelona/merged/effnet_weights/best_model_fold_3.pth',
               '/content/drive/MyDrive/EGD-Barcelona/merged/effnet_weights/best_model_fold_4.pth',]
avg_weights = average_weights(model_paths)
torch.save(avg_weights, '/content/drive/MyDrive/EGD-Barcelona/merged/effnet_weights/avg_kfold_efficientnet.pth')

# %% [markdown]
# ## Now lets test the results obtained with this model

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import numpy as np
from efficientnet import initialize_model
from dataloader import EGDDataset
from torchvision import transforms
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

# Initialize dataset
transform = transforms.Compose([
    transforms.Resize((300, 340)),
    transforms.RandomResizedCrop(224),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

dataset = EGDDataset(
    image_folder="/content/drive/MyDrive/EGD-Barcelona/merged/all_images_mean_cropped",
    label_file="/content/drive/MyDrive/EGD-Barcelona/merged/full_well.xlsx",
    transform=transform
)

# Split data into training, validation, and test sets
total_samples = len(dataset)
train_size = int(0.85 * total_samples)
val_size = total_samples - train_size

train_dataset, val_dataset = random_split(dataset, [train_size, val_size])


# Initialize DataLoader for validation dataset
val_loader = DataLoader(val_dataset, batch_size=16, shuffle=False)

# Initialize the model
num_classes = 3
model = initialize_model(num_classes)

# Load averaged model weights (THEY DON´T SEEM TO WORK WELL, SPECIALLY WRONG FOR CLASS 1 CLASSIFICATION)
avg_model_weights_path = "/content/drive/MyDrive/EGD-Barcelona/merged/effnet_weights/best_model_fold_1.pth"
model.load_state_dict(torch.load(avg_model_weights_path))

# Loss function
criterion = nn.CrossEntropyLoss()

# Initialize metrics
val_loss = 0.0
correct = 0
total = 0
conf_mat = np.zeros((num_classes, num_classes))

# Evaluate the model
model.eval()

with torch.no_grad():
    for images, individual_labels, final_label in val_loader:
        outputs = model(images)
        loss = criterion(outputs, final_label)
        val_loss += loss.item()

        _, predicted = torch.max(outputs.data, 1)
        total += final_label.size(0)
        correct += (predicted == final_label).sum().item()

        conf_mat += confusion_matrix(final_label.cpu(), predicted.cpu(), labels=range(num_classes))

val_loss = val_loss / len(val_loader)
print(f'Val Loss: {val_loss:.4f}, Val Accuracy: {100 * correct / total:.2f}%')
print(f"correctly classified: {correct}, incorrectly classified: {total-correct}")

sns.heatmap(conf_mat, annot=True, cmap='cool')
plt.title("Classification confusion matrix")
plt.ylabel("Actual label")
plt.xlabel("Predicted as")
plt.show()

# Calculate and print per-class accuracy and recall
for i in range(num_classes):
    tp = conf_mat[i, i]
    fn = np.sum(conf_mat[i, :]) - tp
    fp = np.sum(conf_mat[:, i]) - tp
    tn = np.sum(conf_mat) - tp - fn - fp

    accuracy = (tp + tn) / np.sum(conf_mat)
    recall = tp / (tp + fn)

    print(f'Class {i} Accuracy: {accuracy * 100:.2f}%')
    print(f'Class {i} Recall: {recall * 100:.2f}%')
# Out:
# Using cache found in /root/.cache/torch/hub/hankyul2_EfficientNetV2-pytorch_main
# Val Loss: 0.2432, Val Accuracy: 100.00%
# correctly classified: 19, incorrectly classified: 0
# Class 0 Accuracy: 100.00%
# Class 0 Recall: 100.00%
# Class 1 Accuracy: 100.00%
# Class 1 Recall: 100.00%
# Class 2 Accuracy: 100.00%
# Class 2 Recall: 100.00%

# %% [markdown]
# ## Extra

# %%
#@title Create plots for each image and label (stored in drive). Is commented to avoid recomputation at each run
'''
import matplotlib.pyplot as plt

# Create a DataLoader for the entire dataset
# No shuffling, and you can set the batch size to 1 for simplicity
full_loader = DataLoader(dataset, batch_size=1, shuffle=False)

# Initialize a plot counter
plot_counter = 1

# Loop through the entire dataset
for images, individual_labels, final_label in full_loader:
    plt.figure(figsize=(8, 8))

    # Unnormalize the image
    image_unnorm = images[0] * torch.tensor([0.229, 0.224, 0.225]).view(3, 1, 1) + torch.tensor([0.485, 0.456, 0.406]).view(3, 1, 1)

    # Convert to numpy array and transpose axes for displaying
    image_unnorm = image_unnorm.numpy().transpose((1, 2, 0))

    plt.imshow(image_unnorm)

    # Annotate individual and final labels
    plt.title(f"Final Label: {final_label.item()}")
    plt.xlabel(f"Individual Labels: {individual_labels[0].tolist()}")

    # Save the figure
    plt.savefig(f"/content/drive/MyDrive/EGD-Barcelona/merged/plots_well/plot_{plot_counter}.png")

    # Increment plot counter
    plot_counter += 1

    plt.close()
'''

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir logs/
